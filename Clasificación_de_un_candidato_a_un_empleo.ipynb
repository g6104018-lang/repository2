# %% [markdown]
# <a href="https://colab.research.google.com/github/g6104018-lang/repository2/blob/main/Clasificaci%C3%B3n_de_un_candidato_a_un_empleo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dataset sintético con diferentes rangos por habilidad

# %%
import numpy as np
import pandas as pd

# Generar dataset sintético con diferentes rangos por habilidad
n_muestras = 5000
# Habilidades técnicas: 70-100
tec = np.random.randint(70, 101, (n_muestras, 6))
# Habilidades matemáticas: 60-90
mat = np.random.randint(60, 91, (n_muestras, 6))
# Habilidades psicológicas: 50-85
psi = np.random.randint(50, 86, (n_muestras, 6))
# Nombres de columnas
columnas = [
    'python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube',
    'estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado',
    'trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas'
]
# Crear DataFrame
df = pd.DataFrame(np.concatenate([tec, mat, psi], axis=1), columns=columnas)

# %%
# Calcular promedio por grupo y promedio total
prom_tecnologicas = df[['python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube']].mean(axis=1)
prom_matematicas  = df[['estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado']].mean(axis=1)
prom_psicologicas = df[['trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas']].mean(axis=1)
# Promedio total = promedio de los 3 promedios
prom_total = (prom_tecnologicas + prom_matematicas + prom_psicologicas) / 3
# Etiqueta: 1 = apto si promedio total > 80
y = (prom_total > 75).astype(int)
# one-hot encoding
y = pd.get_dummies(y).values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)

# Escalamiento
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
#Obtenemos la etiqueta y
#Obtenemos los conjuntos de entrenamiento y de test

# %%
#red neuronal
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

adam = Adam(learning_rate=0.001)
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#entrenar
history = modelo.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8109 - loss: 0.3887 - val_accuracy: 0.9580 - val_loss: 0.1055
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9594 - loss: 0.0833 - val_accuracy: 0.9670 - val_loss: 0.0736
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9825 - loss: 0.0463 - val_accuracy: 0.9470 - val_loss: 0.1147
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0389 - val_accuracy: 0.9710 - val_loss: 0.0740
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9900 - loss: 0.0270 - val_accuracy: 0.9690 - val_loss: 0.0903
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9898 - loss: 0.0259 - val_accuracy: 0.9700 - val_loss: 0.0713
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9925 - loss: 0.0209 - val_accuracy: 0.9730 - val_loss: 0.0730
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9964 - loss: 0.0139 - val_accuracy: 0.9660 - val_loss: 0.0959
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9964 - loss: 0.0127 - val_accuracy: 0.9710 - val_loss: 0.0835
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9956 - loss: 0.0143 - val_accuracy: 0.9780 - val_loss: 0.0589
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9953 - loss: 0.0110 - val_accuracy: 0.9710 - val_loss: 0.0869
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0088 - val_accuracy: 0.9740 - val_loss: 0.0869
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9770 - val_loss: 0.0610
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 9.1079e-04 - val_accuracy: 0.9750 - val_loss: 0.0726
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0162 - val_accuracy: 0.9620 - val_loss: 0.1133
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9989 - loss: 0.0054 - val_accuracy: 0.9730 - val_loss: 0.1295
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9951 - loss: 0.0106 - val_accuracy: 0.9680 - val_loss: 0.0919
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9981 - loss: 0.0044 - val_accuracy: 0.9660 - val_loss: 0.1226
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9937 - loss: 0.0178 - val_accuracy: 0.9710 - val_loss: 0.0796
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 0.9730 - val_loss: 0.0770
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 8.5322e-04 - val_accuracy: 0.9770 - val_loss: 0.0823
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 3.2356e-04 - val_accuracy: 0.9780 - val_loss: 0.0805
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.0571e-04 - val_accuracy: 0.9790 - val_loss: 0.0782
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.5241e-04 - val_accuracy: 0.9790 - val_loss: 0.0816
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.1025e-04 - val_accuracy: 0.9780 - val_loss: 0.0845
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 8.2031e-05 - val_accuracy: 0.9780 - val_loss: 0.0827
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.5165e-05 - val_accuracy: 0.9780 - val_loss: 0.0871
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 5.0420e-05 - val_accuracy: 0.9800 - val_loss: 0.0873
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 3.4489e-05 - val_accuracy: 0.9780 - val_loss: 0.0901
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 2.9411e-05 - val_accuracy: 0.9800 - val_loss: 0.0906
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 2.1221e-05 - val_accuracy: 0.9800 - val_loss: 0.0931
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 1.5348e-05 - val_accuracy: 0.9800 - val_loss: 0.0977
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.5157e-05 - val_accuracy: 0.9810 - val_loss: 0.0984
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 8.8074e-06 - val_accuracy: 0.9800 - val_loss: 0.0984
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 7.0032e-06 - val_accuracy: 0.9810 - val_loss: 0.1028
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.1086e-06 - val_accuracy: 0.9810 - val_loss: 0.1040
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 3.6449e-06 - val_accuracy: 0.9810 - val_loss: 0.1085
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.7462e-06 - val_accuracy: 0.9810 - val_loss: 0.1093
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.1139e-06 - val_accuracy: 0.9800 - val_loss: 0.1153
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.4996e-06 - val_accuracy: 0.9810 - val_loss: 0.1129
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1218e-06 - val_accuracy: 0.9800 - val_loss: 0.1187
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 8.2646e-07 - val_accuracy: 0.9800 - val_loss: 0.1179
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 6.6093e-07 - val_accuracy: 0.9800 - val_loss: 0.1235
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 4.7520e-07 - val_accuracy: 0.9800 - val_loss: 0.1212
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 3.2027e-07 - val_accuracy: 0.9800 - val_loss: 0.1258
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 2.6936e-07 - val_accuracy: 0.9800 - val_loss: 0.1289
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.9561e-07 - val_accuracy: 0.9800 - val_loss: 0.1345
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.6610e-07 - val_accuracy: 0.9790 - val_loss: 0.1326
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.0975e-07 - val_accuracy: 0.9800 - val_loss: 0.1356
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 9.7626e-08 - val_accuracy: 0.9800 - val_loss: 0.1385

# %%
#evaluar
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

loss, acc = modelo.evaluate(X_test, y_test)
print(f"\n🔹 Loss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.1226
#
# 🔹 Loss: 0.1385  |  Accuracy: 0.9800

# %%
#matriz
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.97
# Apto: 0.99

# %%
#nuevo candidato
nuevo_candidato = np.array([[90, 88, 85, 87, 84, 89,   # técnicas
                             82, 86, 85, 83, 87, 80,   # matemáticas
                             70, 75, 80, 72, 78, 74]]) # psicológicas

nuevo_candidato_scaled = scaler.transform(nuevo_candidato)
pred_nuevo = modelo.predict(nuevo_candidato_scaled)
clase_predicha = np.argmax(pred_nuevo)

print("Evaluación de nuevo candidato:")
print(f"Resultado: {'Apto' if clase_predicha == 1 else 'No Apto'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Evaluación de nuevo candidato:
# Resultado: Apto
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
